# %% [markdown]
# # LetsGrowMore Virtual Internship July-2022

# %% [markdown]
# # Task-1:BEGINNER LEVEL TASK:Iris Flowers Classification ML Project

# %% [markdown]
# # Designed by-IPPILI AMRUTA

# %% [markdown]
# # Dataset Description

# %% [markdown]
# Iris Dataset is considered as the Hello World for data science,Iris is a flowering plant,it contains five columns namely-'Sepal-length','Sepal-width','Petal-length','Petal-width','Class'

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# # Import Dataset

# %%
dataset=pd.read_csv('iris (2).data',names=['Sepal-length','Sepal-width','Petal-length','Petal-width','Class'])

# %%
dataset
# Out:
#      Sepal-length  Sepal-width  Petal-length  Petal-width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset.shape
# Out:
# (150, 5)

# %%
dataset.describe()
# Out:
#        Sepal-length  Sepal-width  Petal-length  Petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal-length  150 non-null    float64
#  1   Sepal-width   150 non-null    float64
#  2   Petal-length  150 non-null    float64
#  3   Petal-width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
X.head()
# Out:
#    Sepal-length  Sepal-width  Petal-length  Petal-width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Class, dtype: object

# %% [markdown]
# # Plotting Data

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X['Sepal-length'],X['Sepal-width'])
plt.xlabel('Sepal-length')
plt.ylabel('Sepal-width')
# Out:
# Text(0, 0.5, 'Sepal-width')

# %%
plt.scatter(X['Petal-length'],X['Petal-width'])
plt.xlabel('Petal-length')
plt.ylabel('Petal-width')
# Out:
# Text(0, 0.5, 'Petal-width')

# %%
import seaborn as sns

# %% [markdown]
# pairplot

# %%
sns.pairplot(dataset)

# %% [markdown]
# Joint plot

# %%
sns.jointplot(x='Sepal-length', y= 'Sepal-width', data = dataset,color='purple')
plt.show()

# %%
sns.jointplot(x='Petal-length', y= 'Petal-width', data = dataset,color='brown')
plt.show()

# %% [markdown]
# Strip Plot

# %%
sns.stripplot(x = dataset['Sepal-length'], y = dataset['Sepal-width'], hue = dataset['Class'], jitter = True,  palette = ['r','b','g'], dodge = False)
# Out:
# <AxesSubplot:xlabel='Sepal-length', ylabel='Sepal-width'>

# %%
sns.stripplot(x = dataset['Petal-length'], y = dataset['Petal-width'], hue = dataset['Class'], jitter = True,  palette = ['r','b','g'], dodge = False)
# Out:
# <AxesSubplot:xlabel='Petal-length', ylabel='Petal-width'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2)

# %%
x_train.shape
# Out:
# (120, 4)

# %% [markdown]
# # Model Training

# %%
knn=KNeighborsClassifier()
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # Model Evaluation and Prediction

# %%
knn.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
knn.predict([[2.3,3.4,6,7.2]])
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
knn.predict([[5.1,3.5,1.4,0.2]])
# Out:
# array(['Iris-setosa'], dtype=object)
